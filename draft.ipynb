# %% [markdown]
# # Data Science Bowl

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2
from plot3D import *
# Out:
# /home/mdindin/Project_Dyskinesia/local/lib/python2.7/site-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
# Get the list of patients
patients = sorted(os.listdir('./Input/'))

# %% [markdown]
# Visualization inspired by Guido Zuidhof

# %%
displayScan(patients[5], [20,60], plt.cm.bone)

# %% [markdown]
# ## Lung Extraction

# %% [markdown]
# What Guido realized is impressive. The one problem it didn't solve was, for me, hypodense and hyperdense nodes, that could be lost through the threshold function ... The main idea I based my following code is about geometrical considerations, to extract the lungs and only the lungs, without missing anything.

# %%
# Get slice i along the Z axis for patient p
img = getImages(patients[5])[70]

# %%
# Observe the different zones in the picture, after transforming it thanks to 
# the Sobol algorithm and the Laplacian filter (edges detection)
cutHist(img, 200, 200)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-6-3319fad255c7> in <module>()
#       1 # Observe the different zones in the picture, after transforming it thanks to
#       2 # the Sobol algorithm and the Laplacian filter (edges detection)
# ----> 3 cutHist(img, 200, 200)
#
# /home/mdindin/Project_Dyskinesia/LungCancer/visual.py in cutHist(img, nSlice, nColum)
#     106 def cutHist(img, nSlice, nColum) :
#     107
# --> 108     thresh = np.vectorize(tresh)
#     109
#     110     sImage = getSobolImage(img)
#
# NameError: global name 'tresh' is not defined

# %%
# Check if the extraction is meaningfull
observeExtraction(img)

# %%
# Compare the extracted lungs of two patients
comparePatients3D(patients[0],patients[5])

# %% [markdown]
# ## Model Development
