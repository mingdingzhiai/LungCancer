# %% [markdown]
# # Data Science Bowl

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
from visual import *
from plot3D import *
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
# Get the list of patients
patients = sorted(os.listdir('./input/sample_images/'))

# %%
# Check if the extraction is meaningfull
observeExtraction(getImages(patients[0])[70])

# %%
# Observe the final results of preprocessing
clear = clearOutsiders(getImages(patients[5])[70], True)

# %%
binaryPlot3D(patients[1])
# Out:
# |-> Ended marching cubes algorithm of patient 0a099f2549429d29b32f349e95fb2244

# %% [markdown]
# ## Elektronn 3D CNN
